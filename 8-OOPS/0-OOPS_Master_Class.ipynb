# %%
class Student:
    def __init__(self, name, roll_no, marks):
        self.name = name
        self.roll_no = roll_no
        self.marks = marks

# %%
student_1 = Student("John", 1, 90)

# %%
student_1.name
# Out:
# 'John'

# %%
student_2 = Student(marks=80, roll_no=2, name="Jane")

# %%
student_2.marks
# Out:
# 80

# %%
class Student:
    def __init__(self, name, roll_no, marks):
        self.name = name
        self.roll_no = roll_no
        self.marks = marks
    
    def study(self):
        print(f"{self.name} is Studying")

    def play(self):
        print(f"{self.name} is Playing")

# %%
student_1 = Student("John", 1, 90)
student_2  = Student("Jane", 2, 80)

student_1.study()
student_2.play()
# Out:
# John is Studying
# Jane is Playing

# %% [markdown]
# # Complex Numbers Class

# %% [markdown]
# ### Question 1: Class for Complex Numbers
#
# Create a Python class named 'ComplexNumber' to represent complex numbers.
#
# Theory:
# A complex number is a number that comprises a real part and an imaginary part.
# It is typically written in the form a + bi, where 'a' is the real part, and 'b' is the imaginary part, and 'i' is the imaginary unit (V-1).
#
# Operations:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Comparison (==, !=)

# %%
class ComplexNumber:
    def __init__(self, real=0.0, imag=0.0):
        self.real = real
        self.imag = imag

    def __str__(self): # magic method
        if self.real == 0.0 and self.imag == 0.0:
            return '0.0i'
        elif self.imag >= 0:
            s = f'{self.real} + {self.imag}i'
        else:
            s = f'{self.real}{self.imag}i'
        return s

    def __add__(self, other):
        return ComplexNumber(self.real+other.real, self.imag+other.imag)
    
    def __sub__(self, other):
        return ComplexNumber(self.real-other.real, self.imag-other.imag)
    
    def __mul__(self, other):
        result_real = self.real*other.real - self.imag*other.imag
        result_imag = self.real*other.imag + self.imag*other.real
        return ComplexNumber(result_real, result_imag)
        
    def __truediv__(self, other):    
        result_real = (self.real*other.real + self.imag*other.imag) / (other.real**2 + other.imag**2)
        result_imag = (self.imag*other.real - self.real*other.imag) / (other.real**2 + other.imag**2)
        return ComplexNumber(result_real, result_imag)
    
    def __eq__(self, other):
        return ComplexNumber(self.real==other.real, self.imag==other.imag)

    def conjugate(self):
        return ComplexNumber(self.real, -self.imag)

# %%
cn1 = ComplexNumber(3, 4)
cn2 = ComplexNumber(4, 5)

# %%
print(cn1 / cn2)
# Out:
# 0.7804878048780488 + 0.024390243902439025i

# %%
print(cn1 * cn2)
# Out:
# -8 + 31i

# %%
cn1.real, cn1.imag
# Out:
# (3, 4)

# %%
cn1.conjugate()
# Out:
# 3 + -5j

# %%
cn1.__str__()
# Out:
# I'm here

# %%
cn1 == cn2
# Out:
# False

# %%
print(cn1.conjugate())
# Out:
# 3-4i
